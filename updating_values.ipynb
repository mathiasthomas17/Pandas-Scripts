# %%
import pandas as pd

# %%
houses = pd.read_csv('../DataAnalysis/data/kc_house_data.csv')
titanic = pd.read_csv('../DataAnalysis/data/titanic.csv')
BTC = pd.read_csv('../DataAnalysis/data/coin_Bitcoin.csv')
countries = pd.read_csv('../DataAnalysis/data/world-happiness-report-2021.csv')

# %% [markdown]
# RENAMING COLS

# %%
mapper = {'Date':'Transaction_Date','Open':'Open_Date'}

# %%
BTC.rename(columns=mapper)
# Out:
#        SNo     Name Symbol     Transaction_Date          High           Low
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000  \
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %% [markdown]
# REPLACE METHODS

# %%
titanic['sex'].replace('female','F')
# Out:
# 0          F
# 1       male
# 2          F
# 3       male
# 4          F
#         ...
# 1304       F
# 1305       F
# 1306    male
# 1307    male
# 1308    male
# Name: sex, Length: 1309, dtype: object

# %% [markdown]
# Replace Mutiple Things

# %%
titanic.sex.replace(['female','male'],['F','M'])
# Out:
# 0       F
# 1       M
# 2       F
# 3       M
# 4       F
#        ..
# 1304    F
# 1305    F
# 1306    M
# 1307    M
# 1308    M
# Name: sex, Length: 1309, dtype: object

# %%
titanic.cabin.replace('?','Unkwon')
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304     Unkwon
# 1305     Unkwon
# 1306     Unkwon
# 1307     Unkwon
# 1308     Unkwon
# Name: cabin, Length: 1309, dtype: object

# %%
# Replace With NONE

# %%
titanic.cabin.replace(['?'],['None'])
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304       None
# 1305       None
# 1306       None
# 1307       None
# 1308       None
# Name: cabin, Length: 1309, dtype: object

# %%
countries.set_index('Country name',inplace=True)

# %%
countries.loc[['Finland','Denmark','Iceland']]
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score
# Country name
# Finland          Western Europe         7.842                           0.032  \
# Denmark          Western Europe         7.620                           0.035
# Iceland          Western Europe         7.554                           0.059
#
#               upperwhisker  lowerwhisker  Logged GDP per capita
# Country name
# Finland              7.904         7.780                 10.775  \
# Denmark              7.687         7.552                 10.933
# Iceland              7.670         7.438                 10.878
#
#               Social support  Healthy life expectancy
# Country name
# Finland                0.954                     72.0  \
# Denmark                0.954                     72.7
# Iceland                0.983                     73.0
#
#               Freedom to make life choices  Generosity
# Country name
# Finland                              0.949      -0.098  \
# ...

# %%
manyb_rooms = houses['bathrooms']>=4

# %%
houses.loc[manyb_rooms,['bedrooms']]  = 'Alot'

# %%
houses
# Out:
#                id             date     price bedrooms  bathrooms  sqft_living
# 0      7129300520  20141013T000000  221900.0        3       1.00         1180  \
# 1      6414100192  20141209T000000  538000.0        3       2.25         2570
# 2      5631500400  20150225T000000  180000.0        2       1.00          770
# 3      2487200875  20141209T000000  604000.0        4       3.00         1960
# 4      1954400510  20150218T000000  510000.0        3       2.00         1680
# ...           ...              ...       ...      ...        ...          ...
# 21608   263000018  20140521T000000  360000.0        3       2.50         1530
# 21609  6600060120  20150223T000000  400000.0        4       2.50         2310
# 21610  1523300141  20140623T000000  402101.0        2       0.75         1020
# 21611   291310100  20150116T000000  400000.0        3       2.50         1600
# 21612  1523300157  20141015T000000  325000.0        2       0.75         1020
#
# ...

# %%
high_quality = houses['grade']>12
great_view = houses['view'] == 4

# %%
houses.loc[high_quality&great_view,['Lux_Level']] = 'ultra'

# %%
houses
# Out:
#                id             date     price bedrooms  bathrooms  sqft_living
# 0      7129300520  20141013T000000  221900.0        3       1.00         1180  \
# 1      6414100192  20141209T000000  538000.0        3       2.25         2570
# 2      5631500400  20150225T000000  180000.0        2       1.00          770
# 3      2487200875  20141209T000000  604000.0        4       3.00         1960
# 4      1954400510  20150218T000000  510000.0        3       2.00         1680
# ...           ...              ...       ...      ...        ...          ...
# 21608   263000018  20140521T000000  360000.0        3       2.50         1530
# 21609  6600060120  20150223T000000  400000.0        4       2.50         2310
# 21610  1523300141  20140623T000000  402101.0        2       0.75         1020
# 21611   291310100  20150116T000000  400000.0        3       2.50         1600
# 21612  1523300157  20141015T000000  325000.0        2       0.75         1020
#
# ...
