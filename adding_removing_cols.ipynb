# %%
import pandas as pd

# %%
houses = pd.read_csv('../DataAnalysis/data/kc_house_data.csv')
titanic = pd.read_csv('../DataAnalysis/data/titanic.csv')
BTC = pd.read_csv('../DataAnalysis/data/coin_Bitcoin.csv')
countries = pd.read_csv('../DataAnalysis/data/world-happiness-report-2021.csv')

# %%
countries.set_index('Country name',inplace=True)

# %%
# countries

# %%
# Drop COl
BTC.drop(labels='Symbol',axis=1)
# Out:
#        SNo     Name                 Date          High           Low
# 0        1  Bitcoin  2013-04-29 23:59:59    147.488007    134.000000  \
# 1        2  Bitcoin  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...                  ...           ...           ...
# 2986  2987  Bitcoin  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 0       134.444000    144.539993  0.000000e+00  1.603769e+09
# ...

# %%
# Drop Two COLS
# axis=1 - Means We are removing a col
BTC.drop(labels=['Symbol','Name'],axis=1)
# Out:
#        SNo                 Date          High           Low          Open
# 0        1  2013-04-29 23:59:59    147.488007    134.000000    134.444000  \
# 1        2  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2        3  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3        4  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4        5  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...    ...                  ...           ...           ...           ...
# 2986  2987  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2988  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2989  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2990  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2991  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# ...

# %%
# Dropping Multiple Cols
BTC.drop(columns=['Symbol','Name'])
# Out:
#        SNo                 Date          High           Low          Open
# 0        1  2013-04-29 23:59:59    147.488007    134.000000    134.444000  \
# 1        2  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2        3  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3        4  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4        5  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...    ...                  ...           ...           ...           ...
# 2986  2987  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2988  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2989  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2990  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2991  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# ...

# %% [markdown]
# INSTEAD OD DELETING COLS YOU CAN CREATE A NEW DF

# %%
newDf = BTC[['Symbol','Name']]

# %%
newDf
# Out:
#      Symbol     Name
# 0       BTC  Bitcoin
# 1       BTC  Bitcoin
# 2       BTC  Bitcoin
# 3       BTC  Bitcoin
# 4       BTC  Bitcoin
# ...     ...      ...
# 2986    BTC  Bitcoin
# 2987    BTC  Bitcoin
# 2988    BTC  Bitcoin
# 2989    BTC  Bitcoin
# 2990    BTC  Bitcoin
#
# [2991 rows x 2 columns]

# %% [markdown]
# DROPPING ROWS

# %%
countries.drop(labels='Finland',axis=0)
# Out:
#               Regional indicator  Ladder score
# Country name
# Denmark           Western Europe         7.620  \
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker
# Country name
# Denmark                                0.035         7.687         7.552  \
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries.drop(labels=['Finland','Denmark','Iceland'],axis=0)
# Out:
#               Regional indicator  Ladder score
# Country name
# Switzerland       Western Europe         7.571  \
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker
# Country name
# Switzerland                            0.036         7.643         7.500  \
# Netherlands                            0.027         7.518         7.410
# Norway                                 0.035         7.462         7.323
# ...

# %%
# Drop By Possition

# %%
countries.drop(countries.index[0:5])
# Out:
#                  Regional indicator  Ladder score
# Country name
# Norway               Western Europe         7.392  \
# Sweden               Western Europe         7.363
# Luxembourg           Western Europe         7.324
# New Zealand   North America and ANZ         7.277
# Austria              Western Europe         7.268
# ...                             ...           ...
# Lesotho          Sub-Saharan Africa         3.512
# Botswana         Sub-Saharan Africa         3.467
# Rwanda           Sub-Saharan Africa         3.415
# Zimbabwe         Sub-Saharan Africa         3.145
# Afghanistan              South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker
# Country name
# Norway                                 0.035         7.462         7.323  \
# Sweden                                 0.036         7.433         7.293
# Luxembourg                             0.037         7.396         7.252
# ...

# %% [markdown]
# Adding New STATIC Columns

# %%
titanic['Species'] = 'Human'

# %%
titanic
# Out:
#       pclass  survived                                             name
# 0          1         1                    Allen, Miss. Elisabeth Walton  \
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat
# ...

# %% [markdown]
# Adding  Columns At a Specific Position

# %%
titanic.insert(0,'County','Makueni')

# %%
titanic
# Out:
#        County  pclass  survived
# 0     Makueni       1         1  \
# 1     Makueni       1         1
# 2     Makueni       1         0
# 3     Makueni       1         0
# 4     Makueni       1         0
# ...       ...     ...       ...
# 1304  Makueni       3         0
# 1305  Makueni       3         0
# 1306  Makueni       3         0
# 1307  Makueni       3         0
# 1308  Makueni       3         0
#
#                                                  name     sex     age  sibsp
# 0                       Allen, Miss. Elisabeth Walton  female      29      0  \
# 1                      Allison, Master. Hudson Trevor    male  0.9167      1
# 2                        Allison, Miss. Helen Loraine  female       2      1
# 3                Allison, Mr. Hudson Joshua Creighton    male      30      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female      25      1
# ...                                               ...     ...     ...    ...
# ...

# %% [markdown]
# Adding Dyamic COLS

# %%
titanic['sum'] = titanic['parch'] + titanic['sibsp']

# %%
titanic[['sum','parch','sibsp']]
# Out:
#       sum  parch  sibsp
# 0       0      0      0
# 1       3      2      1
# 2       3      2      1
# 3       3      2      1
# 4       3      2      1
# ...   ...    ...    ...
# 1304    1      0      1
# 1305    1      0      1
# 1306    0      0      0
# 1307    0      0      0
# 1308    0      0      0
#
# [1309 rows x 3 columns]

# %% [markdown]
# MORE EXAMPLES

# %%
houses['housesSqrft'] = houses['price']/houses['sqft_living']

# %%
houses.sort_values('housesSqrft',ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms
# 19336  6021500970  20150407T000000   874950.0         2       1.00  \
# 4013    724069059  20140509T000000  2400000.0         3       2.25
# 10446  1118000320  20150508T000000  3400000.0         4       4.00
# 8623   6303400395  20150130T000000   325000.0         1       0.75
# 9314   4389200610  20141201T000000   903000.0         2       1.50
# ...           ...              ...        ...       ...        ...
# 1385   3342700465  20150123T000000   250000.0         3       1.50
# 17197  5111400086  20140512T000000   110000.0         3       1.00
# 13825  5637200450  20141017T000000   257000.0         5       2.75
# 3785    723049156  20140523T000000   149000.0         3       1.00
# 18262  2891000610  20141211T000000   148900.0         4       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above
# 19336         1080      4000     1.0           0     0  ...        1080  \
# ...

# %% [markdown]
# BIGEST BITC Change

# %%
BTC.set_index('Date')
# Out:
#                       SNo     Name Symbol          High           Low
# Date
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000  \
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# ...                   ...      ...    ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %%
BTC['H_L_Change'] = BTC['Close'] - BTC['Open']

# %%
change = BTC[['Date','H_L_Change']]

# %%
change.sort_values('H_L_Change',ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: >
