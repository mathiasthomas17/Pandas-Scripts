# %%
import pandas as pd

# %% [markdown]
# **FILTERING DATAFRAMES**

# %% [markdown]
# Filtering With BOOLEAN SERIES

# %%
houses = pd.read_csv('../DataAnalysis/data/kc_house_data.csv')
titanic = pd.read_csv('../DataAnalysis/data/titanic.csv')
BTC = pd.read_csv('../DataAnalysis/data/coin_Bitcoin.csv')

# %%
top_five = titanic.head()

# %%
top_five.sex == 'male'
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: sex, dtype: bool

# %%
top_five[top_five.sex == 'male']
# Out:
#    pclass  survived                                             name   sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  male
# 1       1         1                   Allison, Master. Hudson Trevor  male
# 2       1         0                     Allison, Miss. Helen Loraine  male
# 3       1         0             Allison, Mr. Hudson Joshua Creighton  male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  male
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
#top five age <=10
top_five[top_five.age <='10']
# Out:
#    pclass  survived                            name   sex     age  sibsp  \
# 1       1         1  Allison, Master. Hudson Trevor  male  0.9167      1
#
#    parch  ticket    fare    cabin embarked boat body  \
# 1      2  113781  151.55  C22 C26        S   11    ?
#
#                          home.dest
# 1  Montreal, PQ / Chesterville, ON

# %%
top_five[top_five.age >='10']
# Out:
#    pclass  survived                                             name   sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  male
# 2       1         0                     Allison, Miss. Helen Loraine  male
# 3       1         0             Allison, Mr. Hudson Joshua Creighton  male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  male
#
#   age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29      0      0   24160  211.3375       B5        S    2    ?
# 2   2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3  30      1      2  113781    151.55  C22 C26        S    ?  135
# 4  25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# FILTERING WITH COMPARISSON OPERATOR

# %%
titanic[titanic.sex == 'female']
# Out:
#       pclass  survived                                             name
# 0          1         1                    Allen, Miss. Elisabeth Walton  \
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat
# ...

# %%
#People Who Servived
titanic[titanic.survived == 1]
# Out:
#       pclass  survived                                             name
# 0          1         1                    Allen, Miss. Elisabeth Walton  \
# 1          1         1                   Allison, Master. Hudson Trevor
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1277       3         1                             Vartanian, Mr. David
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked   boat
# ...

# %%
titanic[titanic.age == '18']
# Out:
#       pclass  survived                                               name  \
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 198        1         1  Marvin, Mrs. Daniel Warner (Mary Graham Carmic...
# 228        1         0         Penasco y Castellana, Mr. Victor de Satode
# 250        1         1                         Ryerson, Miss. Emily Borie
# 270        1         1     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 289        1         1                                Taussig, Miss. Ruth
# 326        2         0                         Andrew, Mr. Edgardo Samuel
# 331        2         0                           Bailey, Mr. Percy Andrew
# 386        2         0                          Davies, Mr. Charles Henry
# 394        2         0                                Dibden, Mr. William
# 395        2         1                                Doling, Miss. Elsie
# 405        2         0                          Fahlstrom, Mr. Arne Jonas
# ...

# %%
titanic[titanic.pclass != 1].pclass.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
titanic[titanic.pclass != 1].pclass.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='pclass'>

# %%
houses[houses.price > 22000]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses[houses.bathrooms > 7]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 12777  1225069038  20140505T000000  2280000.0         7       8.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 7252         12050     27600     2.5           0     3  ...     13
# 8546          4050      6504     2.0           0     0  ...      7
# 9254          9890     31374     2.0           0     4  ...     13
# 12777        13540    307752     3.0           0     4  ...     12
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 7252         8570           3480      1910          1987    98102  47.6298
# 8546         4050              0      1996             0    98144  47.5923
# ...

# %% [markdown]
# Between Method

# %%
houses[houses.price.between(20000,250000)]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 8      2414600126  20150415T000000  229500.0         3       1.00
# 18       16000397  20141205T000000  189000.0         2       1.00
# 19     7983200060  20150424T000000  230000.0         3       1.00
# ...           ...              ...       ...       ...        ...
# 21451  7140700690  20150312T000000  239950.0         3       1.75
# 21470   121039156  20150109T000000  249000.0         3       1.00
# 21550   880000205  20140729T000000  249000.0         3       2.00
# 21572  6056111067  20140707T000000  230000.0         3       1.75
# 21602   844000965  20140626T000000  224000.0         3       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses[houses.bedrooms.between(9,15)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 4235   2902200015  20150106T000000   700000.0         9       3.00
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
# 18443  8823901445  20150313T000000   934000.0         9       3.00
# 19254  8812401450  20141229T000000   660000.0        10       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 4096          3830      6988     2.5           0     0  ...      7
# 4235          3680      4400     2.0           0     0  ...      7
# ...

# %%
houses[houses.bedrooms.between(9,15)].bedrooms.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='bedrooms'>

# %% [markdown]
# IS IN Method

# %%
netflix =pd.read_csv('DataAnalysis/data/netflix_titles.csv',sep='|',index_col=0)

# %%
countries = ['India','Japan','South Korea']

# %%
netflix[netflix.country.isin(countries)]
# Out:
#      show_id     type                                              title  \
# 4         s5  TV Show                                       Kota Factory
# 24       s25    Movie                                              Jeans
# 39       s40  TV Show                                       Chhota Bheem
# 50       s51  TV Show                                      Dharmakshetra
# 51       s52    Movie  InuYasha the Movie 2: The Castle Beyond the Lo...
# ...      ...      ...                                                ...
# 8773   s8774    Movie                                Yanda Kartavya Aahe
# 8775   s8776  TV Show                                    Yeh Meri Family
# 8798   s8799    Movie                                           Zed Plus
# 8799   s8800    Movie                                              Zenda
# 8806   s8807    Movie                                             Zubaan
#
#                      director  \
# 4                         NaN
# ...

# %%
# netflix
mask = netflix['rating'].isin(['TV-MA','R','PG-13'])

# %%
netflix[mask]
# Out:
#      show_id     type                  title                 director  \
# 0         s1    Movie   Dick Johnson Is Dead          Kirsten Johnson
# 1         s2  TV Show          Blood & Water                      NaN
# 2         s3  TV Show              Ganglands          Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans                      NaN
# 4         s5  TV Show           Kota Factory                      NaN
# ...      ...      ...                    ...                      ...
# 8791   s8792    Movie            Young Adult            Jason Reitman
# 8798   s8799    Movie               Zed Plus  Chandra Prakash Dwivedi
# 8801   s8802    Movie                Zinzana          Majid Al Ansari
# 8802   s8803    Movie                 Zodiac            David Fincher
# 8804   s8805    Movie             Zombieland          Ruben Fleischer
#
#                                                    cast  \
# 0                                                   NaN
# ...

# %% [markdown]
# COMBINING CONDITIONS

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
mask = titanic.survived == 0 & titanic.sex == 'female'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:364, in na_logical_op(x, y, op)
#     355 try:
#     356     # For exposition, write:
#     357     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     362     # Then Cases where this goes through without raising include:
#     363     #  (xint or xbool) and (yint or bool)
# --> 364     result = op(x, y)
#     365 except TypeError:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: unsupported operand type(s) for &: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
women  = titanic.sex == 'female'
died = titanic.survived == 1

# %%
titanic[women & died]
# Out:
#       pclass  survived                                               name  \
# 2          1         0                       Allison, Miss. Helen Loraine
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 105        1         0                           Evans, Miss. Edith Corse
# 169        1         0                         Isham, Miss. Ann Elizabeth
# 286        1         0             Straus, Mrs. Isidor (Rosalie Ida Blun)
# ...      ...       ...                                                ...
# 1273       3         0                 Vander Planke, Miss. Augusta Maria
# 1276       3         0  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1304       3         0                               Zabour, Miss. Hileni
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
houses[(houses['waterfront'] == 1) & (houses['price']>500000)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 49      822039084  20150311T000000  1350000.0         3       2.50
# 230    8096000060  20150413T000000   655000.0         2       1.75
# 246    2025069065  20140929T000000  2400000.0         4       2.50
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# 457    2122039094  20141126T000000   705000.0         3       3.00
# ...           ...              ...        ...       ...        ...
# 19984  2025069140  20150317T000000  1898000.0         3       2.50
# 20325   518500480  20140811T000000  3000000.0         3       3.50
# 20767  8043700105  20150417T000000  2300000.0         4       4.00
# 21201   518500460  20141008T000000  2230000.0         3       3.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 49            2753     65005     1.0           1     2  ...      9
# ...

# %%
houses[(houses['view']==4) & (houses['grade']>=11)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 540     622049114  20150218T000000  2125000.0         3       2.50
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 2085   8106100105  20141114T000000  3850000.0         4       4.25
# 2444   7524900003  20141210T000000  3278000.0         2       1.75
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 2713   7851980260  20140730T000000  1110000.0         5       3.50
# 3157   1827200265  20140911T000000  1899000.0         2       2.75
# 3586   9272200090  20150204T000000  1598890.0         4       4.50
# 4013    724069059  20140509T000000  2400000.0         3       2.25
# 4190   2303900090  20140729T000000  2880500.0         4       2.50
# 4406   3505100756  20141106T000000  2050000.0         4       3.00
# ...

# %% [markdown]
# Using OR

# %%
houses[(houses['price']>=1000000) | (houses['bathrooms']>=5)]

# houses[(houses[houses['bathrooms'] >=6]) | (houses[houses['bedrooms'] >=10])]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 21     2524049179  20140826T000000  2000000.0         3       2.75
# 49      822039084  20150311T000000  1350000.0         3       2.50
# 69     1802000060  20140612T000000  1325000.0         5       2.25
# 70     1525059190  20140912T000000  1040000.0         5       3.25
# ...           ...              ...        ...       ...        ...
# 21590  7430200100  20140514T000000  1222500.0         4       3.50
# 21593  8672200110  20150317T000000  1088000.0         5       3.75
# 21597   191100405  20150421T000000  1575000.0         4       3.25
# 21600   249000205  20141015T000000  1537000.0         5       3.75
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 5             5420    101930     1.0           0     0  ...     11
# ...

# %% [markdown]
# BITWISE NEGATION

# %%
df = titanic.head()

# %%
women = df.sex == 'female'
df[women]
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29      0      0   24160  211.3375       B5        S    2    ?
# 2   2      1      2  113781    151.55  C22 C26        S    ?    ?
# 4  25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 2  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
#Negate
df[~women]
# Out:
#    pclass  survived                                  name   sex     age  \
# 1       1         1        Allison, Master. Hudson Trevor  male  0.9167
# 3       1         0  Allison, Mr. Hudson Joshua Creighton  male      30
#
#    sibsp  parch  ticket    fare    cabin embarked boat body  \
# 1      1      2  113781  151.55  C22 C26        S   11    ?
# 3      1      2  113781  151.55  C22 C26        S    ?  135
#
#                          home.dest
# 1  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON

# %%
# houses.info()

# %%
# houses_baths_more_than_5 | houses_beds_more_than_5

# %% [markdown]
# ISNA - Missing Values

# %%
no_director = netflix[netflix['director'].isna()]

# %%
no_director
# Out:
#      show_id     type                                title director  \
# 1         s2  TV Show                        Blood & Water      NaN
# 3         s4  TV Show                Jailbirds New Orleans      NaN
# 4         s5  TV Show                         Kota Factory      NaN
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia      NaN
# 14       s15  TV Show      Crime Stories: India Detectives      NaN
# ...      ...      ...                                  ...      ...
# 8795   s8796  TV Show                      Yu-Gi-Oh! Arc-V      NaN
# 8796   s8797  TV Show                           Yunus Emre      NaN
# 8797   s8798  TV Show                            Zak Storm      NaN
# 8800   s8801  TV Show                   Zindagi Gulzar Hai      NaN
# 8803   s8804  TV Show                          Zombie Dumb      NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
netflix[netflix['director'].notna()]
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %% [markdown]
# BASIC PLOTTIND

# %%
female = titanic[titanic['sex']=='female']
male = titanic[titanic['sex']=='male']

# %%
female.survived.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
male.survived.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
