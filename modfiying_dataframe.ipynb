# %%
import pandas as pd

# %%
BTC = pd.read_csv('DataAnalysis/data/coin_Bitcoin.csv')
houses = pd.read_csv('DataAnalysis/data/kc_house_data.csv')
titanic = pd.read_csv('DataAnalysis/data/titanic.csv')

# %% [markdown]
# Dropping Columns

# %%
# Returns a new DF
# Does not Mutate Original
BTC.drop(labels='Symbol',axis=1)
# Out:
#        SNo     Name                 Date          High           Low  \
# 0        1  Bitcoin  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...                  ...           ...           ...
# 2986  2987  Bitcoin  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 0       134.444000    144.539993  0.000000e+00  1.603769e+09
# ...

# %%
# Dropping Multiple
BTC.drop(labels=['Symbol','SNo','Name'],axis='columns')
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
# Using drop Cols instead of labels
BTC.drop(columns=['Name','Symbol'])
# Out:
#        SNo                 Date          High           Low          Open  \
# 0        1  2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1        2  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2        3  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3        4  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4        5  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...    ...                  ...           ...           ...           ...
# 2986  2987  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2988  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2989  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2990  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2991  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# ...

# %% [markdown]
# Dropping ROws

# %%
BTC.set_index('Name')
# Out:
#           SNo Symbol                 Date          High           Low  \
# Name
# Bitcoin     1    BTC  2013-04-29 23:59:59    147.488007    134.000000
# Bitcoin     2    BTC  2013-04-30 23:59:59    146.929993    134.050003
# Bitcoin     3    BTC  2013-05-01 23:59:59    139.889999    107.720001
# Bitcoin     4    BTC  2013-05-02 23:59:59    125.599998     92.281898
# Bitcoin     5    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...       ...    ...                  ...           ...           ...
# Bitcoin  2987    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# Bitcoin  2988    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# Bitcoin  2989    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# Bitcoin  2990    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# Bitcoin  2991    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
#                  Open         Close        Volume     Marketcap
# Name
# ...

# %%
BTC.drop(labels='Bitcoin',axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 BTC.drop(labels='Bitcoin',axis=0)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# ...

# %%
# You can drop multiple rows as in cols above

# %% [markdown]
# Adding New Column

# %%
titanic['Species'] = 'Human'

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# Adding at a specified Location
# 0 is index
houses.insert(0,'County','King County')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15340\3632182109.py in ?()
#       1 # Adding at a specified Location
#       2 # 0 is index
# ----> 3 houses.insert(0,'County','King County')
#
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    4927                 "'self.flags.allows_duplicate_labels' is False."
#    4928             )
#    4929         if not allow_duplicates and column in self.columns:
#    4930             # Should this be a different kind of error??
# -> 4931             raise ValueError(f"cannot insert {column}, already exists")
#    4932         if not is_integer(loc):
#    4933             raise TypeError("loc must be int")
#    4934         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert County, already exists

# %%
houses
# Out:
#             County          id             date     price  bedrooms  \
# 0      King County  7129300520  20141013T000000  221900.0         3
# 1      King County  6414100192  20141209T000000  538000.0         3
# 2      King County  5631500400  20150225T000000  180000.0         2
# 3      King County  2487200875  20141209T000000  604000.0         4
# 4      King County  1954400510  20150218T000000  510000.0         3
# ...            ...         ...              ...       ...       ...
# 21608  King County   263000018  20140521T000000  360000.0         3
# 21609  King County  6600060120  20150223T000000  400000.0         4
# 21610  King County  1523300141  20140623T000000  402101.0         2
# 21611  King County   291310100  20150116T000000  400000.0         3
# 21612  King County  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  grade  \
# 0           1.00         1180      5650     1.0           0  ...      7
# ...

# %% [markdown]
# DYNAMIC COLUMNS

# %%
titanic['Total Siblings'] = titanic.sibsp + titanic.parch

# %%
titanic[['sibsp','parch','Total Siblings']]
# Out:
#       sibsp  parch  Total Siblings
# 0         0      0               0
# 1         1      2               3
# 2         1      2               3
# 3         1      2               3
# 4         1      2               3
# ...     ...    ...             ...
# 1304      1      0               1
# 1305      1      0               1
# 1306      0      0               0
# 1307      0      0               0
# 1308      0      0               0
#
# [1309 rows x 3 columns]

# %% [markdown]
# Examples

# %%
# houses #Prices per sqrft
houses['Price PSQRT']  = houses['price']/houses['sqft_living']

# %%
houses.sort_values('Price PSQRT',ascending=False)
# Out:
#             County          id             date      price  bedrooms  \
# 19336  King County  6021500970  20150407T000000   874950.0         2
# 4013   King County   724069059  20140509T000000  2400000.0         3
# 10446  King County  1118000320  20150508T000000  3400000.0         4
# 8623   King County  6303400395  20150130T000000   325000.0         1
# 9314   King County  4389200610  20141201T000000   903000.0         2
# ...            ...         ...              ...        ...       ...
# 1385   King County  3342700465  20150123T000000   250000.0         3
# 17197  King County  5111400086  20140512T000000   110000.0         3
# 13825  King County  5637200450  20141017T000000   257000.0         5
# 3785   King County   723049156  20140523T000000   149000.0         3
# 18262  King County  2891000610  20141211T000000   148900.0         4
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  \
# ...

# %%
houses.sort_values('Price PSQRT',ascending=False).head(10)['zipcode'].plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# BITCON EXAMPLE

# %%
BTC.set_index('Date')
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# ...                   ...      ...    ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %%
BTC['change']=BTC['Close'] - BTC['Open']

# %%
BTC.sort_values('change',ascending=False).head(5).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Reanaming Columns and ROWS

# %%
BTC
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
# Rename Cols
mapper = {'Name':'Currency Name','Symbol':'Currency Symbol'}

# %%
BTC.rename(columns=mapper) #Use inplace to mutate original DF
# Out:
#        SNo Currency Name Currency Symbol                 Date          High  \
# 0        1       Bitcoin             BTC  2013-04-29 23:59:59    147.488007
# 1        2       Bitcoin             BTC  2013-04-30 23:59:59    146.929993
# 2        3       Bitcoin             BTC  2013-05-01 23:59:59    139.889999
# 3        4       Bitcoin             BTC  2013-05-02 23:59:59    125.599998
# 4        5       Bitcoin             BTC  2013-05-03 23:59:59    108.127998
# ...    ...           ...             ...                  ...           ...
# 2986  2987       Bitcoin             BTC  2021-07-02 23:59:59  33939.588699
# 2987  2988       Bitcoin             BTC  2021-07-03 23:59:59  34909.259899
# 2988  2989       Bitcoin             BTC  2021-07-04 23:59:59  35937.567147
# 2989  2990       Bitcoin             BTC  2021-07-05 23:59:59  35284.344430
# 2990  2991       Bitcoin             BTC  2021-07-06 23:59:59  35038.536363
#
# ...

# %%
# Same Can Be Done For Index/Rows

# %% [markdown]
# Replace Value

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic['sex'].replace('female','F')
# Out:
# 0          F
# 1       male
# 2          F
# 3       male
# 4          F
#         ...
# 1304       F
# 1305       F
# 1306    male
# 1307    male
# 1308    male
# Name: sex, Length: 1309, dtype: object

# %%
titanic['sex'].replace(['female','male'],['F','M'])
# Out:
# 0       F
# 1       M
# 2       F
# 3       M
# 4       F
#        ..
# 1304    F
# 1305    F
# 1306    M
# 1307    M
# 1308    M
# Name: sex, Length: 1309, dtype: object

# %%
titanic['age'].replace('?','I Dont Know').value_counts()
# Out:
# age
# I Dont Know    263
# 24              47
# 22              43
# 21              41
# 30              40
#               ...
# 66               1
# 0.6667           1
# 76               1
# 67               1
# 26.5             1
# Name: count, Length: 99, dtype: int64

# %%
# To replace something with NONE Ypu must use list notation
# [None]
titanic['age'].replace(['?'],[None]).value_counts(dropna=False)
# Out:
# age
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: count, Length: 99, dtype: int64
